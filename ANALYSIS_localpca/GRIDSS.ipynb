# %%
from cyvcf2 import VCF
import numpy as np

# %%
bnds = list()

i = 0

gridss = list()

for variant in VCF('visualization/gridss_merged.vcf.gz')('NC_044283.2'): # or VCF('some.bcf')
    i = i + 1
    variant.POS
    gridss.append(variant.POS)

# %%
gridss
# Out:
# [1,
#  1086,
#  1096,
#  1183,
#  2233,
#  2243,
#  2293,
#  39002,
#  39024,
#  47207,
#  47212,
#  47947,
#  47947,
#  47958,
#  47959,
#  50802,
#  54529,
#  59766,
#  59776,
#  69237,
#  69258,
#  78952,
#  81379,
#  81480,
#  81529,
#  81612,
#  81621,
#  84068,
#  91871,
#  91872,
#  91873,
#  91891,
#  93966,
#  93979,
#  94739,
#  97615,
#  97640,
#  107205,
#  107225,
#  108517,
#  112023,
#  112034,
#  112477,
#  112482,
#  113251,
#  113258,
#  130345,
#  130444,
#  130456,
#  136808,
#  136831,
#  144854,
#  144857,
#  144916,
#  144954,
#  144959,
#  155028,
#  155039,
#  163625,
#  163630,
#  164319,
#  164930,
#  164950,
#  170426,
#  170500,
#  171229,
#  171234,
#  171238,
#  171244,
#  172949,
#  173135,
#  173448,
#  174147,
#  174223,
#  174228,
#  181346,
#  182526,
#  182529,
#  182531,
#  184027,
#  187688,
#  187875,
#  191117,
#  193262,
#  193263,
#  193287,
#  193289,
#  195166,
#  196337,
#  196338,
#  196350,
#  196351,
#  196760,
#  198553,
#  198558,
# ...

# %%
i
# Out:
# 6296

# %%
np.savetxt("gridss_s8.txt", gridss, fmt='%1d')
